# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf

# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Input, Dense
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-73c4a380a34a> in <module>
#       1 import numpy as np
# ----> 2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#       4
#       5 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# # Introduction to Deep Learning
# ## Live Demos

# %%
# (2a + 3b)^2

# %%
a = tf.constant(300)
b = tf.constant(100)

# %%
tf.pow(tf.add(tf.multiply(2, a), tf.multiply(3, b)), 2)
# Out:
# <tf.Tensor: id=23, shape=(), dtype=int32, numpy=8100>

# %%
(2 * 30 + 3 * 10) ** 2
# Out:
# 8100

# %%
(2 * a + 3 * b) ** 2
# Out:
# <tf.Tensor: id=53, shape=(), dtype=int32, numpy=810000>

# %%
bank_data = pd.read_csv("data/bank.csv", sep = ";", true_values = ["yes"], false_values = ["no"])

# %%
bank_data
# Out:
#       age            job  marital  education  default  balance  housing  \
# 0      30     unemployed  married    primary    False     1787    False
# 1      33       services  married  secondary    False     4789     True
# 2      35     management   single   tertiary    False     1350     True
# 3      30     management  married   tertiary    False     1476     True
# 4      59    blue-collar  married  secondary    False        0     True
# ...   ...            ...      ...        ...      ...      ...      ...
# 4516   33       services  married  secondary    False     -333     True
# 4517   57  self-employed  married   tertiary     True    -3313     True
# 4518   57     technician  married  secondary    False      295    False
# 4519   28    blue-collar  married  secondary    False     1137    False
# 4520   44   entrepreneur   single   tertiary    False     1136     True
#
#        loan   contact  day month  duration  campaign  pdays  previous  \
# 0     False  cellular   19   oct        79         1     -1         0
# 1      True  cellular   11   may       220         1    339         4
# 2     False  cellular   16   apr       185         1    330         1
# 3      True   unknown    3   jun       199         4     -1         0
# 4     False   unknown    5   may       226         1     -1         0
# ...     ...       ...  ...   ...       ...       ...    ...       ...
# 4516  False  cellular   30   jul       329         5     -1         0
# 4517   True   unknown    9   may       153         1     -1         0
# 4518  False  cellular   19   aug       151        11     -1         0
# 4519  False  cellular    6   feb       129         4    211         3
# 4520   True  cellular    3   apr       345         2    249         7
#
#      poutcome      y
# 0     unknown  False
# 1     failure  False
# 2     failure  False
# 3     unknown  False
# 4     unknown  False
# ...       ...    ...
# 4516  unknown  False
# 4517  unknown  False
# 4518  unknown  False
# 4519    other  False
# 4520    other  False
#
# [4521 rows x 17 columns]

# %%
bank_data.shape
# Out:
# (4521, 17)

# %%
plt.hist(bank_data.age, bins = 20)
plt.xlabel("Age")
plt.show()

# %%
bank_data.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default        bool
# balance       int64
# housing        bool
# loan           bool
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y              bool
# dtype: object

# %%
bank_data = pd.get_dummies(bank_data)

# %%
bank_data.shape
# Out:
# (4521, 49)

# %%
bank_data = bank_data.astype(np.float64)

# %%
bank_data.dtypes
# Out:
# age                    float64
# default                float64
# balance                float64
# housing                float64
# loan                   float64
# day                    float64
# duration               float64
# campaign               float64
# pdays                  float64
# previous               float64
# y                      float64
# job_admin.             float64
# job_blue-collar        float64
# job_entrepreneur       float64
# job_housemaid          float64
# job_management         float64
# job_retired            float64
# job_self-employed      float64
# job_services           float64
# job_student            float64
# job_technician         float64
# job_unemployed         float64
# job_unknown            float64
# marital_divorced       float64
# marital_married        float64
# marital_single         float64
# education_primary      float64
# education_secondary    float64
# education_tertiary     float64
# education_unknown      float64
# contact_cellular       float64
# contact_telephone      float64
# contact_unknown        float64
# month_apr              float64
# month_aug              float64
# month_dec              float64
# month_feb              float64
# month_jan              float64
# month_jul              float64
# month_jun              float64
# month_mar              float64
# month_may              float64
# month_nov              float64
# month_oct              float64
# month_sep              float64
# poutcome_failure       float64
# poutcome_other         float64
# poutcome_success       float64
# poutcome_unknown       float64
# dtype: object

# %%
attributes = bank_data.drop(["y"], axis = 1)

# %%
labels = bank_data["y"]

# %%
min_max_scale = lambda col: (col - tf.reduce_min(col)) / (tf.reduce_max(col) - tf.reduce_min(col))

# %%
num_columns = attributes.shape[1]
transformed_columns = [min_max_scale(attributes.values[:, i]) for i in range(num_columns)]

# %%
bank_data_transformed = tf.stack(transformed_columns, axis = 1)

# %%
plt.hist(bank_data_transformed.numpy()[:, 0], bins = 20)
plt.show()

# %%
bank_data_transformed.shape
# Out:
# TensorShape([4521, 48])

# %%
labels = labels.astype(int).values

# %%
labels_onehot = tf.one_hot(labels, depth = 2)

# %%
logistic_regression = Sequential([
    Input(shape = num_columns),
    Dense(2, activation = "sigmoid")
])

# %%
logistic_regression.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 2)                 98
# =================================================================
# Total params: 98
# Trainable params: 98
# Non-trainable params: 0
# _________________________________________________________________

# %%
logistic_regression.compile(optimizer = "adam", loss = "categorical_crossentropy")

# %%
logistic_regression.fit(x = bank_data_transformed, y = labels_onehot, epochs = 10)
# Out:
# Train on 4521 samples
# Epoch 1/10
# 4521/4521 [==============================] - 1s 187us/sample - loss: 0.5822
# Epoch 2/10
# 4521/4521 [==============================] - 0s 88us/sample - loss: 0.4134
# Epoch 3/10
# 4521/4521 [==============================] - 0s 89us/sample - loss: 0.3619
# Epoch 4/10
# 4521/4521 [==============================] - 0s 98us/sample - loss: 0.3452
# Epoch 5/10
# 4521/4521 [==============================] - 0s 95us/sample - loss: 0.3371
# Epoch 6/10
# 4521/4521 [==============================] - 0s 94us/sample - loss: 0.3314
# Epoch 7/10
# 4521/4521 [==============================] - 0s 91us/sample - loss: 0.3266
# Epoch 8/10
# 4521/4521 [==============================] - 0s 103us/sample - loss: 0.3222
# Epoch 9/10
# 4521/4521 [==============================] - 0s 95us/sample - loss: 0.3185
# Epoch 10/10
# 4521/4521 [==============================] - 0s 91us/sample - loss: 0.3150

# %%
logistic_regression.layers[0].kernel
# Out:
# <tf.Variable 'dense_18/kernel:0' shape=(48, 2) dtype=float32, numpy=
# array([[-1.28551304e-01, -1.15231827e-01],
#        [ 6.78090453e-02, -1.72376111e-01],
#        [-3.04092050e-01,  1.24338359e-01],
#        [-2.88565755e-02,  2.45095313e-01],
#        [ 3.52804065e-02,  2.11943686e-01],
#        [ 2.24532008e-01,  2.32950211e-01],
#        [ 3.20443392e-01,  1.59478486e-02],
#        [-9.62647200e-02,  2.63140380e-01],
#        [-1.82248995e-01,  1.41745806e-01],
#        [-1.92882538e-01, -2.51176983e-01],
#        [ 2.76539266e-01, -3.39200228e-01],
#        [ 1.54557347e-01, -2.08568975e-01],
#        [-1.36272788e-01, -1.46160454e-01],
#        [-1.54905140e-01,  3.42110813e-01],
#        [ 2.19656408e-01, -3.53331864e-02],
#        [ 1.98430002e-01, -3.16548854e-01],
#        [ 1.58808053e-01,  5.19512296e-02],
#        [ 3.02102566e-02,  7.35525489e-02],
#        [-1.06309235e-01, -2.80668616e-01],
#        [-2.06442431e-01, -1.27281398e-01],
#        [ 3.19497168e-01,  2.23144472e-01],
#        [-3.25975239e-01,  1.72017992e-01],
#        [-2.36178100e-01, -3.35670143e-01],
#        [-3.22899401e-01, -1.49480432e-01],
#        [ 7.90787935e-02, -1.96656272e-01],
#        [-1.56846851e-01,  3.13326418e-02],
#        [ 2.78173029e-01, -3.36782068e-01],
#        [ 1.47820026e-01,  1.21996015e-01],
#        [-2.72396654e-01,  9.36532915e-02],
#        [-1.29085660e-01,  1.81467712e-01],
#        [-2.01541498e-01, -1.29672140e-01],
#        [ 1.40493482e-01, -1.71541214e-01],
#        [ 3.32935393e-01, -1.33031309e-02],
#        [ 1.79962873e-01, -2.49630392e-01],
#        [ 1.28510594e-01,  1.87168360e-01],
#        [-2.15881556e-01, -2.67039090e-01],
#        [-2.58801818e-01, -1.90655977e-01],
#        [ 3.31997871e-01,  3.45894873e-01],
#        [-1.82781383e-01,  9.82066095e-02],
#        [ 2.54562557e-01,  1.96250081e-02],
#        [ 1.19148612e-01,  7.61625767e-02],
#        [-2.53370583e-01, -7.52582252e-02],
#        [-2.67312229e-01,  4.84816730e-02],
#        [-1.54277205e-01,  8.90577137e-02],
#        [-3.05488706e-02,  2.01318026e-01],
#        [ 7.30350614e-02,  2.69859910e-01],
#        [ 2.32014894e-01, -8.99418294e-02],
#        [ 1.96333408e-01,  1.85072422e-04]], dtype=float32)>

# %%
neural_network = Sequential([
    Input(shape = num_columns),
    Dense(30, activation = "relu"),
    Dense(20, activation = "relu"),
    Dense(10, activation = "relu"),
    Dense(2, activation = "sigmoid")
])

# %%
neural_network.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_20 (Dense)             (None, 30)                1470
# _________________________________________________________________
# dense_21 (Dense)             (None, 20)                620
# _________________________________________________________________
# dense_22 (Dense)             (None, 10)                210
# _________________________________________________________________
# dense_23 (Dense)             (None, 2)                 22
# =================================================================
# Total params: 2,322
# Trainable params: 2,322
# Non-trainable params: 0
# _________________________________________________________________

# %%
neural_network.compile(optimizer = "adam", loss = "categorical_crossentropy")

# %%
neural_network.fit(x = bank_data_transformed, y = labels_onehot, epochs = 10)
# Out:
# Train on 4521 samples
# Epoch 1/10
# 4521/4521 [==============================] - 1s 114us/sample - loss: 0.1356
# Epoch 2/10
# 4521/4521 [==============================] - 1s 121us/sample - loss: 0.1336
# Epoch 3/10
# 4521/4521 [==============================] - 1s 112us/sample - loss: 0.1321
# Epoch 4/10
# 4521/4521 [==============================] - 1s 120us/sample - loss: 0.1328
# Epoch 5/10
# 4521/4521 [==============================] - 0s 110us/sample - loss: 0.1271
# Epoch 6/10
# 4521/4521 [==============================] - 1s 111us/sample - loss: 0.1253
# Epoch 7/10
# 4521/4521 [==============================] - 0s 105us/sample - loss: 0.1257
# Epoch 8/10
# 4521/4521 [==============================] - 1s 123us/sample - loss: 0.1215
# Epoch 9/10
# 4521/4521 [==============================] - 1s 114us/sample - loss: 0.1200
# Epoch 10/10
# 4521/4521 [==============================] - 0s 109us/sample - loss: 0.1149
